# %%
# list_name = uti.cell_name_list[i].replace('/', '_')    
# df = pd.read_excel("EconomicTable.xlsx", sheet_name="Н_Э")
# arr = df.to_numpy()
# # print("df ", df.columns.values)
# columns_names = df.columns.values
# data_matrix= arr[:,1:]
# xsize = data_matrix[0].size
# ysize = data_matrix[:,0].size

# threshold_percent = 0.6
# threshold = threshold_percent * ysize
# print("threshold is ", threshold)


# print("x size", xsize, "y size", ysize)
# non_zero_factor_list = []
# dominant_factors_name_list = []
# pareto_percent = 0.25
# pareto_threshold = int(xsize * pareto_percent)
# for i in range(xsize):
#     print("columns_names i", columns_names[i+1])
#     column = data_matrix[:, i]
#     print("column", column)
    
#     # print("data_matrix\n", data_matrix[:,0])
#     hist, bin_edges = np.histogram(column, bins = real_bins)
#     print("hist", hist)
#     print("bin edges", bin_edges)

#     max_hist_value = np.max(hist)
#     hist_value = max_hist_value if max_hist_value>=threshold else 0
#     print("hist_value", hist_value)
#     if max_hist_value>=threshold:
#         hist_index = np.where(hist==hist_value)[0][0]
#         print("hist index", hist_index)
# #         print("bin edges", bin_edges[hist_index])

#         first_bin_edge = bin_edges[hist_index]
#         second_bin_edge = bin_edges[hist_index + 1]
#         print("first_bin_edge", first_bin_edge)
#         print("second_bin_edge", second_bin_edge)
#         # good_elements = data_matrix[np.logical_and(data_matrix >= bin_edges[0], data_matrix <= bin_edges[1])]
#         elements_in_bin = column[ (column >=first_bin_edge) * (column <= second_bin_edge)]
#         print("elements_in_bin", elements_in_bin)
#         one_factor_mean_value = np.mean(elements_in_bin)
#         non_zero_factor_list.append(one_factor_mean_value)
#         dominant_factors_name_list.append(columns_names[i+1])
#     else:
#         one_factor_mean_value=0

#     print("one_factor_mean_value", one_factor_mean_value, "\n\n")
# # print(new_bin_edges)

# print("non zero factors list", non_zero_factor_list)
# print("pareto threshold", pareto_threshold)
# if len(non_zero_factor_list)>= 10 :
#     ind = np.argpartition(non_zero_factor_list, -pareto_threshold)[-pareto_threshold:]
#     print("ind", ind)
#     table_value = sum([non_zero_factor_list[i] for i in ind])    
# else:
#     table_value = sum(non_zero_factor_list)
    

# print("table_value", table_value)
# print("dominant_factors_name_list ", dominant_factors_name_list)
    
# plt.hist(data_matrix[:,0], bins = 5, range=[0, 1], edgecolor='black',)
# # plt.show()
#         self.factors = list(self.df1.columns.values)
#         self.dominant_factors = [ self.factors[i + 1] for i in min_value_indexes ]
